# %% [markdown]
# <a href="https://colab.research.google.com/github/Harmony-Group-ML/Session-5/blob/main/class_separation_2features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **نمایش جدایی کلاس‌ها با دو بهترین ویژگی**

# %%
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

plt.figure(figsize=(7,5))
for i, species in enumerate(iris.target_names):
    plt.scatter(
        df[df['target'] == i]['petal length (cm)'],
        df[df['target'] == i]['petal width (cm)'],
        label=species
    )

plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Iris Species Separation by Petal Features')
plt.legend()
plt.show()

# %% [markdown]
# **:نتیجه**
# \
#    بیشترین توانایی را در جدا کردن کلاس های دیتاست
# آیریس دارند.petal length & petal width ویژگی های
